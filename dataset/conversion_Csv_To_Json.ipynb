# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import csv, json
import pandas as pd
import numpy as np

# %%
resultadosRatings = {}
df_movies = pd.read_csv('movies.csv')
df_ratings = pd.read_csv('ratings.csv')
df_links = pd.read_csv('links.csv')

df_merge1 = pd.merge(left=df_movies,right=df_ratings,left_on='movieId',right_on='movieId')
df_general = pd.merge(left=df_merge1,right=df_links,left_on='movieId',right_on='movieId')

df_general.drop_duplicates()
df_general.drop(columns='imdbId')
df_general.drop(columns='timestamp')
df_general.drop(columns='userId')

df_general.to_csv ('./export_df.csv', index = False, header=True)

def buscar(id:int) -> float:
    suma = 0;
    promedio=0;
    div = 0
    cont=0
    for i in df_general['movieId']:
        cont+=1
        if i == id:
            suma+=df_general.iloc[cont-1,4]
            div +=1
    if div > 0:
        return suma/div
    else:
        return 0.0

buscar(1)

#mirar merge pandas
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
df_movies = '.\movies.csv'
data = {}
data2 = {}
with open(df_movies,encoding="utf8") as cvsFile:
    lectorCsv = csv.DictReader(cvsFile)
    for filas in lectorCsv:
        ids = filas['movieId']
        data[ids] = filas

for i in data:
    data[i]['rating'] = 0
    #print(type(i))
    
def buscar(id:int) -> float:
    suma = 0;
    promedio=0;
    div = 0
    cont=0
    for i in df_general['movieId']:
        cont+=1
        if i == id:
            suma+=df_general.iloc[cont-1,4]
            div +=1
    if div > 0:
        return suma/div
    else:
        return 0.0

# %%
for id in data:
    data[id]['rating'] = round(buscar(int(id)),2)
    print('iteriacion:',id)
print(data)
# Out:
# iteriacion: 1
# iteriacion: 2
# iteriacion: 3
# iteriacion: 4
# iteriacion: 5
# iteriacion: 6
# iteriacion: 7
# iteriacion: 8
# iteriacion: 9
# iteriacion: 10
# iteriacion: 11
# iteriacion: 12
# iteriacion: 13
# iteriacion: 14
# iteriacion: 15
# iteriacion: 16
# iteriacion: 17
# iteriacion: 18
# iteriacion: 19
# iteriacion: 20
# iteriacion: 21
# iteriacion: 22
# iteriacion: 23
# iteriacion: 24
# iteriacion: 25
# iteriacion: 26
# iteriacion: 27
# iteriacion: 28
# iteriacion: 29
# iteriacion: 30
# iteriacion: 31
# iteriacion: 32
# iteriacion: 34
# iteriacion: 36
# iteriacion: 38
# iteriacion: 39
# iteriacion: 40
# iteriacion: 41
# iteriacion: 42
# iteriacion: 43
# iteriacion: 44
# iteriacion: 45
# iteriacion: 46
# iteriacion: 47
# iteriacion: 48
# iteriacion: 49
# iteriacion: 50
# iteriacion: 52
# iteriacion: 53
# iteriacion: 54
# iteriacion: 55
# iteriacion: 57
# iteriacion: 58
# iteriacion: 60
# iteriacion: 61
# iteriacion: 62
# iteriacion: 63
# iteriacion: 64
# iteriacion: 65
# ...

# %%
NombreJson='.\DataSetMovies2.json'

with open(NombreJson,'w') as jsonFile:
    jsonFile.write(json.dumps(data, indent=4))
# Out:
# 1524250
